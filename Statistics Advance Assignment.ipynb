# %% [markdown]
# **Q1: What is Estimation Statistics? Explain point estimate and interval estimate.**

# %% [markdown]
# **Estimation Statistics:**
#
# Estimation statistics is a branch of statistics that deals with the process of estimating the value of a population parameter based on a sample. Point estimate and interval estimate are two main types of estimation.
#
# **Point Estimate:**
#
# A point estimate is a single value that is used to estimate the value of a population parameter. For example, if we want to estimate the mean height of all adults in the United States, we could take a sample of 100 adults and calculate the average height of those 100 adults. The average height of the sample would be a point estimate of the mean height of all adults in the United States.
#
# **Interval Estimate:**
#
# An interval estimate is a range of values that is used to estimate the value of a population parameter. For example, if we want to estimate the mean height of all adults in the United States, we could take a sample of 100 adults and calculate the average height of those 100 adults. We could then construct a 95% confidence interval for the mean height of all adults in the United States. The 95% confidence interval would be a range of values that we are 95% confident contains the true mean height of all adults in the United States.

# %% [markdown]
# **Q2. Write a Python function to estimate the population mean using a sample mean and standard deviation.**

# %%
import numpy as np
import scipy.stats as stats

def estimate_population_mean(sample_mean, sample_std, sample_size, confidence_level=0.95):
  """
  Estimates the population mean using a sample mean and standard deviation.

  Args:
    sample_mean: The mean of the sample.
    sample_std: The standard deviation of the sample.
    sample_size: The size of the sample.
    confidence_level: The desired confidence level for the interval estimate.

  Returns:
    A tuple containing the lower and upper bounds of the confidence interval.
  """

  # Calculate the margin of error.
  margin_of_error = sample_std * np.sqrt(1 / sample_size) * stats.t.ppf((1 + confidence_level) / 2, sample_size - 1)

  # Calculate the lower and upper bounds of the confidence interval.
  lower_bound = sample_mean - margin_of_error
  upper_bound = sample_mean + margin_of_error

  return lower_bound, upper_bound

# %% [markdown]
# **Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.**

# %% [markdown]
# **Hypothesis testing** is a statistical method used to determine whether a hypothesis about a population parameter is supported by the available evidence from a sample.
#
# **Why is hypothesis testing used?**
#
# Hypothesis testing is used to:
#
# * Make inferences about a population based on a sample.
# * Test the effectiveness of a new treatment or intervention.
# * Compare two or more groups.
# * Identify factors that are associated with a particular outcome.
#
# **Importance of hypothesis testing:**
#
# Hypothesis testing is important because it allows researchers to make decisions about a population based on limited information. It also provides a framework for evaluating the strength of evidence in support of a hypothesis.
#
# **Steps in hypothesis testing:**
#
# 1. State the null hypothesis (H0) and the alternative hypothesis (H1).
# 2. Collect a sample from the population.
# 3. Calculate the test statistic.
# 4. Determine the p-value.
# 5. Make a decision about the null hypothesis.
#
# **Interpreting the results of hypothesis testing:**
#
# * If the p-value is less than the significance level, then the null hypothesis is rejected.
# * If the p-value is greater than the significance level, then the null hypothesis is not rejected.
#
# **Conclusion:**
#
# Hypothesis testing is a powerful tool that can be used to make decisions about a population based on limited information. It is important to understand the steps involved in hypothesis testing and how to interpret the results.

# %% [markdown]
# **Q4. Create a hypothesis that states whether the average weight of male college students is greater than the average weight of female college students.**

# %% [markdown]
# H0: μ_male <= μ_female
# H1: μ_male > μ_female

# %% [markdown]
# **Q5. Write a Python script to conduct a hypothesis test on the difference between two population means,given a sample from each population.**

# %%
import numpy as np
from scipy import stats

sample1 = np.random.normal(10, 2, size=20)
sample2 = np.random.normal(8, 2, size=20)


# Define the null and alternative hypotheses
H0 = np.mean(sample1) - np.mean(sample2) == 0
H1 = np.mean(sample1) - np.mean(sample2) != 0

# Set the significance level
alpha = 0.05

# Calculate the test statistic
t_statistic, p_value = stats.ttest_ind(sample1, sample2)

# Make a decision about the null hypothesis
if p_value < alpha:
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")
# Out:
# Reject the null hypothesis

# %% [markdown]
# **Q6: What is a null and alternative hypothesis? Give some examples.**

# %% [markdown]
# **Null hypothesis (H0):**
#
# - States that there is no significant difference between two groups or that a certain parameter has a specific value.
# - Example: The average height of men and women is the same.
#
# **Alternative hypothesis (H1):**
#
# - States that there is a significant difference between two groups or that a certain parameter has a different value than the one stated in the null hypothesis.
# - Example: The average height of men is greater than the average height of women.
#
# **Other examples:**
#
# - H0: The new drug has no effect on blood pressure.
# - H1: The new drug lowers blood pressure.
#
# - H0: The coin is fair.
# - H1: The coin is biased towards heads.

# %% [markdown]
# **Q7: Write down the steps involved in hypothesis testing.**

# %% [markdown]
# 1. State the null hypothesis (H0) and the alternative hypothesis (H1).
# 2. Collect a sample from the population.
# 3. Calculate the test statistic.
# 4. Determine the p-value.
# 5. Make a decision about the null hypothesis.

# %% [markdown]
# **Q8. Define p-value and explain its significance in hypothesis testing.**

# %% [markdown]
# A p-value is the probability of obtaining a test statistic as extreme as or more extreme than the one that was actually observed, assuming that the null hypothesis is true.
#
# The p-value is significant in hypothesis testing because it helps us to determine whether or not to reject the null hypothesis. If the p-value is less than the significance level, then we reject the null hypothesis. If the p-value is greater than the significance level, then we fail to reject the null hypothesis.
#
# The p-value is a measure of the strength of the evidence against the null hypothesis. The smaller the p-value, the stronger the evidence against the null hypothesis.

# %% [markdown]
# **Q9. Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom parameter set to 10.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t

# Generate the data
df = 10
x = np.linspace(-5, 5, 1000)

# Calculate the probability density function
pdf = t.pdf(x, df)

# Create the plot
plt.plot(x, pdf)
plt.xlabel("Value")
plt.ylabel("Probability density")
plt.title("Student's t-distribution (df = 10)")
plt.show()

# %% [markdown]
# **Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two random samples of equal size and a null hypothesis that the population means are equal.**

# %%
import numpy as np
from scipy.stats import ttest_ind

# Generate two random samples of equal size
sample1 = np.random.normal(10, 2, size=20)
sample2 = np.random.normal(8, 2, size=20)

# Set the null hypothesis
H0 = np.mean(sample1) - np.mean(sample2) == 0

# Calculate the test statistic and p-value
t_statistic, p_value = ttest_ind(sample1, sample2)

# Print the results
print("t-statistic:", t_statistic)
print("p-value:", p_value)

# Make a decision about the null hypothesis
if p_value < 0.05:
  print("Reject the null hypothesis")
else:
  print("Fail to reject the null hypothesis")
# Out:
# t-statistic: 4.481742771063217
# p-value: 6.602081221089721e-05
# Reject the null hypothesis

# %% [markdown]
# **Q11: What is Student’s t distribution? When to use the t-Distribution.**

# %% [markdown]
# **Student's t distribution:**
#
# The Student's t distribution, also known as the t distribution, is a continuous probability distribution that is similar to the normal distribution, but has heavier tails. The t distribution is used when the sample size is small and the population standard deviation is unknown.
#
# **When to use the t-Distribution:**
#
# The t distribution is used in the following situations:
#
# * To test the hypothesis that the mean of a population is equal to a specific value.
# * To compare the means of two populations.
# * To construct confidence intervals for the mean of a population.
#
# **Properties of the t distribution:**
#
# * The t distribution is symmetric around its mean.
# * The t distribution has a bell-shaped curve.
# * The t distribution has heavier tails than the normal distribution.
# * The shape of the t distribution depends on the degrees of freedom.
# * The degrees of freedom are equal to the sample size minus one.
#
# **Advantages of using the t distribution:**
#
# * The t distribution is more robust than the normal distribution to violations of the normality assumption.
# * The t distribution is more accurate than the normal distribution when the sample size is small.
#
# **Disadvantages of using the t distribution:**
#
# * The t distribution is more difficult to calculate than the normal distribution.
# * The t distribution has a wider spread than the normal distribution.
#
# **Conclusion:**
#
# The t distribution is a useful tool for statistical inference when the sample size is small and the population standard deviation is unknown.

# %% [markdown]
# **Q12: What is t-statistic? State the formula for t-statistic.**

# %% [markdown]
# The t-statistic is a measure of how far the sample mean is from the hypothesized population mean, in units of the standard error of the mean. It is calculated as follows:
#
# t = (x̄ - μ) / (s / √n)
#
# where:
#
# * x̄ is the sample mean
# * μ is the hypothesized population mean
# * s is the sample standard deviation
# * n is the sample size

# %% [markdown]
# **Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random sample of 50 days and find the sample mean revenue to be `$500` with a standard deviation of `$50`.Estimate the population mean revenue with a 95% confidence interval.**

# %%
import numpy as np
import scipy.stats as stats

# Calculate the sample mean and standard deviation
sample_mean = 500
sample_std = 50

# Set the sample size and confidence level
sample_size = 50
confidence_level = 0.95

# Calculate the margin of error
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std / np.sqrt(sample_size))

# Calculate the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Print the confidence interval
print("95% confidence interval:", (lower_bound, upper_bound))
# Out:
# 95% confidence interval: (486.1409617565032, 513.8590382434968)

# %% [markdown]
# **Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.**

# %%
# Set the null and alternative hypotheses
# Assume Blood pressure value is 'B'
# H0: New drug will decrease blood pressure by 10mmHg, (mu = B-10)
# H1: New drug value will not decrease blood pressure by 10mmHg, (mu != B-10)

import scipy.stats as stats
# assume
B=150
# Given values
mu_0 = B-10  # Hypothesized mean
x_bar = B-8  # Sample mean
s = 3  # Sample standard deviation
n = 100  # Sample size
alpha = 0.05  # Significance level

# Calculate the test statistic
t_score = (x_bar - mu_0) / (s / (n ** 0.5))

# Calculate the critical t-value (two-tailed test)
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)

# Print the results
print(f"Test statistic: {t_score}")
print(f"Critical t-value: {t_critical}")

# Check if we should reject the null hypothesis
if abs(t_score) > t_critical:
    print("We reject the null hypothesis.")
else:
    print("We fail to reject the null hypothesis.")
# Out:
# Test statistic: 6.666666666666667
# Critical t-value: 1.9842169515086827
# We reject the null hypothesis.

# %% [markdown]
# **Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5 pounds with a significance level of 0.01.**

# %%
# Set the null and alternative hypotheses
# H0: mu >= 5 (True mean weight is greater than or equal to 5 pounds)
# H1: mu < 5 (True mean weight is less than 5 pounds)

# Given values
mu_0 = 5  # Hypothesized mean
x_bar = 4.8  # Sample mean
s = 0.5  # Sample standard deviation
n = 25  # Sample size
alpha = 0.01  # Significance level

# Calculate the test statistic
t_score = (x_bar - mu_0) / (s / (n ** 0.5))

# Calculate the critical t-value (left-tailed test)
t_critical = stats.t.ppf(alpha, df=n-1)

# Print the results
print(f"Test statistic: {t_score}")
print(f"Critical t-value: {t_critical}")

# Check if we should reject the null hypothesis
if t_score < t_critical:
    print("We reject the null hypothesis.")
else:
    print("We fail to reject the null hypothesis.")
# Out:
# Test statistic: -2.0000000000000018
# Critical t-value: -2.4921594731575762
# We fail to reject the null hypothesis.

# %% [markdown]
# **Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two groups are equal with a significance level of 0.01.**

# %%
# Set the null and alternative hypotheses
# H0: mu1 = mu2 (Population means are equal)
# H1: mu1 != mu2 (Population means are not equal)

# Given values
x1 = 80  # Sample mean for group 1
s1 = 10  # Sample standard deviation for group 1
n1 = 30  # Sample size for group 1
x2 = 75  # Sample mean for group 2
s2 = 8  # Sample standard deviation for group 2
n2 = 40  # Sample size for group 2
alpha = 0.01  # Significance level

# Calculate the pooled variance
sp = np.sqrt(((n1 - 1) * s1**2 + (n2 - 1) * s2**2) / (n1 + n2 - 2))

# Calculate the test statistic
t_score = (x1 - x2) / (sp * np.sqrt(1/n1 + 1/n2))

# Calculate the critical t-value (two-tailed test)
t_critical = stats.t.ppf(1 - alpha/2, df=n1 + n2 - 2)

# Print the results
print(f"Test statistic: {t_score}")
print(f"Critical t-value: {t_critical}")

# Check if we should reject the null hypothesis
if abs(t_score) > t_critical:
    print("We reject the null hypothesis.")
else:
    print("We fail to reject the null hypothesis.")
# Out:
# We fail to reject the null hypothesis.

# %% [markdown]
# **Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard deviation of 1.5. Estimate the population mean with a 99% confidence interval.**

# %%
import numpy as np
from scipy import stats

# Given values
sample_mean = 4
sample_std = 1.5
sample_size = 50
confidence_level = 0.99

# Calculate the margin of error
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std / np.sqrt(sample_size))

# Calculate the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Print the confidence interval
print(f"99% confidence interval: ({lower_bound}, {upper_bound})")
# Out:
# 99% confidence interval: (3.4535840896844654, 4.546415910315535)
